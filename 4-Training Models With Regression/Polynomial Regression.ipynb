# %% [markdown]
# ### Polynomial Regression
#
# If your data points clearly will not fit a linear regression (a straight line through all data points), it might be ideal for polynomial regression. Polynomial regression, like linear regression, uses the relationship between the variables x and y to find the best way to draw a line through the data points.

# %%
# Let's generate some nonlinear data
import numpy as np
np.random.seed(42)
m = 100
X = 6 * np.random.rand(m,1) - 3
y = 0.5 * X **2 + X + 2 + np.random.randn(m,1)

# %%
# let's see our generated data distribution
import matplotlib.pyplot as plt
colors = np.random.rand(m)
plt.scatter(X,y, c=colors)
plt.title("Randomly generate some nonlinear data")
plt.xlabel("X")
plt.ylabel("Y")
plt.show()

# %% [markdown]
# Clearly shows that the generate data will not fit into a straight line. So let's use sklearn PolynomialFeatures class to trnsform our training data.

# %%
from sklearn.preprocessing import PolynomialFeatures

poly_features = PolynomialFeatures(degree=2, include_bias=False)
X_poly = poly_features.fit_transform(X)

print(X[0])
print(X_ploy[0])
# Out:
# [-0.75275929]
# [-0.75275929  0.56664654]

# %% [markdown]
# X_poly now contains the actual X and the squred of X. We can use LinearRegression model to our extended data.

# %%
from sklearn.linear_model import LinearRegression
lin_reg = LinearRegression()

# %%
lin_reg.fit(X_poly,y)
# Out:
# LinearRegression()

# %%
print(lin_reg.intercept_, lin_reg.coef_)
# Out:
# [1.78134581] [[0.93366893 0.56456263]]
